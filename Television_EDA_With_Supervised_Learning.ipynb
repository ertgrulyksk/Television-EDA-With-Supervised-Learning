# %% [markdown]
# <a href="https://colab.research.google.com/github/ertgrulyksk/Television-EDA-With-Supervised-Learning/blob/main/Television_EDA_With_Supervised_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd

# %%
df = pd.read_csv('TELEVISION.csv',error_bad_lines=False)
df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 276: expected 12 fields, saw 14\nSkipping line 366: expected 12 fields, saw 13\nSkipping line 595: expected 12 fields, saw 13\n'
#   Product_Name  Stars  Ratings  Reviews current_price     MRP  \
# 0        Croma    4.2     1773      217         ₹7990  ₹20000
# 1        Adsun    3.8     6742      930         ₹8699  ₹21999
# 2           LG    4.4    38870     3443        ₹16499  ₹21990
# 3      OnePlus    4.3   101256     9189        ₹16499  ₹21999
# 4       Xiaomi    4.3     3120      305        ₹15499  ₹24999
#
#                                       channel  \
# 0                  HD Ready 1366 x 768 Pixels
# 1              Netflix|Disney+Hotstar|Youtube
# 2  Netflix|Prime Video|Disney+Hotstar|Youtube
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882 entries, 0 to 881
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Name      882 non-null    object
#  1   Stars             882 non-null    float64
#  2   Ratings           882 non-null    int64
#  3   Reviews           882 non-null    int64
#  4   current_price     882 non-null    object
#  5   MRP               882 non-null    object
#  6   channel           882 non-null    object
#  7   Operating_system  882 non-null    object
#  8   Picture_qualtiy   882 non-null    object
#  9   Speaker           882 non-null    object
#  10  Frequency         882 non-null    object
#  11  Image_url         882 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 82.8+ KB

# %%
df.shape
# Out:
# (882, 12)

# %%
df.isnull().sum()
# Out:
# Product_Name        0
# Stars               0
# Ratings             0
# Reviews             0
# current_price       0
# MRP                 0
# channel             0
# Operating_system    0
# Picture_qualtiy     0
# Speaker             0
# Frequency           0
# Image_url           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 207

# %%
df[df.duplicated()]
# Out:
#     Product_Name  Stars  Ratings  Reviews current_price     MRP  \
# 27         Adsun    3.8     6742      930         ₹8699  ₹21999
# 31         Croma    4.2        0        0        ₹11990  ₹25000
# 34         Croma    4.2     1773      217         ₹7990  ₹20000
# 35         Adsun    3.8     6742      930         ₹8999  ₹29999
# 39         Croma    3.9        0        0        ₹18990  ₹30000
# ..           ...    ...      ...      ...           ...     ...
# 864        Croma    4.2     1773      217         ₹7990  ₹20000
# 868        Adsun    3.8     6742      930         ₹8699  ₹21999
# 872        Croma    4.2        0        0        ₹11990  ₹25000
# 876        Adsun    3.8     6742      930         ₹8999  ₹29999
# 880        Adsun    3.8     6742      930         ₹6199  ₹12999
#
#                                         channel  \
# 27               Netflix|Disney+Hotstar|Youtube
# 31   Netflix|Prime Video|Disney+Hotstar|Youtube
# 34                   HD Ready 1366 x 768 Pixels
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (675, 12)

# %%
df.nunique()
# Out:
# Product_Name         56
# Stars                24
# Ratings             135
# Reviews             124
# current_price       359
# MRP                 312
# channel              37
# Operating_system     43
# Picture_qualtiy      63
# Speaker              85
# Frequency            59
# Image_url           591
# dtype: int64

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.countplot(df['Product_Name'])
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.distplot(df['Stars'],kde=True)
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.distplot(df['Ratings'],kde=True)
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.distplot(df['Reviews'],kde=True)
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.countplot(df['current_price'])
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.countplot(df['MRP'])
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['MRP'] = df['MRP'].str.replace('₹','')
df['current_price'] = df['current_price'].str.replace('₹','')

# %%
df['MRP'] = df['MRP'].astype('int')
df['current_price'] = df['current_price'].astype('int')

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.boxplot(x='Stars',y="MRP",data=df)
plt.show()

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.boxplot(x='Ratings',y="MRP",data=df)
plt.show()

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.boxplot(x='channel',y="MRP",data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.boxplot(x='Operating_system',y="MRP",data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
plt_1 = plt.figure(figsize=(16, 10))
sns.boxplot(x='Picture_qualtiy',y="MRP",data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
plt_1 = plt.figure(figsize=(16, 10))
sns.boxplot(x='Speaker',y="MRP",data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
plt_1 = plt.figure(figsize=(16, 10))
sns.boxplot(x='Frequency',y="MRP",data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
df['Product_Name'].value_counts()
# Out:
# SAMSUNG        103
# LG              87
# SONY            38
# kinger          37
# TCL             27
# MOTOROLA        22
# Vu              21
# Croma           20
# Adsun           18
# Thomson         18
# Nokia           17
# Mi              14
# KODAK           14
# Sansui          12
# Lloyd           11
# Panasonic       11
# Haier           11
# iFFALCON        11
# Hyundai         10
# Hisense          9
# iMEE             9
# PHILIPS          9
# Coocaa           8
# Yuwa             8
# realme           8
# MarQ             8
# Micromax         7
# Blaupunkt        7
# acer             7
# OnePlus          7
# TOSHIBA          7
# Dyanora          6
# JVC              5
# Candes           5
# Compaq           5
# ONIDA            5
# HUIDI            5
# CORNEA           4
# IMPEX            4
# Xiaomi           4
# Infinix          3
# RGL              3
# BPL              3
# InnoQ            3
# LumX             3
# Bush             3
# Nacson           3
# ...

# %%
plt_1 = plt.figure(figsize=(16, 10))
df['Product_Name'].value_counts().plot(kind='bar')

# %%
plt_1 = plt.figure(figsize=(16, 10))
sns.barplot(x=df['Product_Name'],y=df['MRP'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Operating_system'].value_counts()
# Out:
# Operating System: Android                293
# Operating System: Tizen                   82
# Operating System: WebOS                   77
# Operating System: Android Based           49
# 20 W Speaker Output                       32
# Operating System: Linux based             14
# 16 W Speaker Output                       13
# Operating System: Google TV               11
# 20 Speaker Output                         10
# Operating System: VIDAA                   10
# Ultra HD (4K) 3840 x 2160 Pixels           9
# 20W Speaker Output                         9
# 10 W Speaker Output                        8
# Operating System: Linux                    8
# Full HD 1920 x 1080 Pixels                 7
# Ultra HD (4K) 3840x2160 Pixels             6
# Operating System: FireTv OS 6              5
# 40 W Speaker Output                        3
# 14 W Speaker Output                        2
# Operating System: Coolita                  2
# 20 WATT Speaker Output                     2
# ...

# %%
df['Operating_system'] = df['Operating_system'].apply(lambda x:1 if 'Android' in x else 0)

# %%
df.head()
# Out:
#   Product_Name  Stars  Ratings  Reviews  current_price    MRP  \
# 0        Croma    4.2     1773      217           7990  20000
# 1        Adsun    3.8     6742      930           8699  21999
# 2           LG    4.4    38870     3443          16499  21990
# 3      OnePlus    4.3   101256     9189          16499  21999
# 4       Xiaomi    4.3     3120      305          15499  24999
#
#                                       channel  Operating_system  \
# 0                  HD Ready 1366 x 768 Pixels                 0
# 1              Netflix|Disney+Hotstar|Youtube                 1
# 2  Netflix|Prime Video|Disney+Hotstar|Youtube                 0
# 3  Netflix|Prime Video|Disney+Hotstar|Youtube                 1
# 4  Netflix|Prime Video|Disney+Hotstar|Youtube                 1
#
#               Picture_qualtiy              Speaker           Frequency  \
# 0          60 Hz Refresh Rate   2 x HDMI | 2 x USB     1 Year Warranty
# ...

# %%
df['Operating_system'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Operating_system'],y=df['MRP'])

# %%
sns.barplot(x=df['Operating_system'],y=df['current_price'])

# %%
df['channel'].value_counts()
# Out:
# Netflix|Prime Video|Disney+Hotstar|Youtube             303
# Netflix|Disney+Hotstar|Youtube                         171
# HD Ready 1366 x 768 Pixels                              47
# Netflix|Youtube                                         28
# Netflix|Prime Video|Youtube                             21
# Prime Video|Disney+Hotstar|Youtube                      18
# Full HD 1920 x 1080 Pixels                              14
# Ultra HD (4K) 3840 x 2160 Pixels                        13
# Operating System: WebOS                                  6
# Disney+Hotstar|Youtube                                   6
# Operating System: Tizen                                  5
# Netflix|Prime Video|Apple TV|Disney+Hotstar|Youtube      4
# Youtube                                                  4
# Operating System: Android                                3
# HD Ready 1366*768 Pixels                                 3
# HD Ready 1366 X 768 Pixels                               3
# ...

# %%
df['channel'] = df['channel'].map(lambda x: 1 if x=='Netflix' or x=='Youtube' else 0)

# %%
df.head()
# Out:
#   Product_Name  Stars  Ratings  Reviews  current_price    MRP  channel  \
# 0        Croma    4.2     1773      217           7990  20000        0
# 1        Adsun    3.8     6742      930           8699  21999        0
# 2           LG    4.4    38870     3443          16499  21990        0
# 3      OnePlus    4.3   101256     9189          16499  21999        0
# 4       Xiaomi    4.3     3120      305          15499  24999        0
#
#    Operating_system             Picture_qualtiy              Speaker  \
# 0                 0          60 Hz Refresh Rate   2 x HDMI | 2 x USB
# 1                 1  HD Ready 1366 x 768 Pixels  20 W Speaker Output
# 2                 0  HD Ready 1366 x 768 Pixels  10 W Speaker Output
# 3                 1  HD Ready 1366 x 768 Pixels  20 W Speaker Output
# 4                 1  HD Ready 1366 x 768 Pixels  20 W Speaker Output
#
#             Frequency                                          Image_url
# ...

# %%
df['channel'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['channel'],y=df['MRP'])

# %%
sns.barplot(x=df['channel'],y=df['current_price'])

# %%
df['Picture_qualtiy'].value_counts()
# Out:
# Ultra HD (4K) 3840 x 2160 Pixels    305
# HD Ready 1366 x 768 Pixels          101
# Full HD 1920 x 1080 Pixels           77
# 60 Hz Refresh Rate                   76
# 20 W Speaker Output                  10
#                                    ...
# Full HD 1366x777 Pixels               1
# Full HD 1366x779 Pixels               1
# Full HD 1920*1080 Pixels              1
# Full HD 1366x799 Pixels               1
# 16 Speaker Output                     1
# Name: Picture_qualtiy, Length: 63, dtype: int64

# %%
df['Picture_qualtiy'] = df['Picture_qualtiy'].apply(lambda x:1 if 'Ultra HD (4K)' in x else 0)

# %%
df['Picture_qualtiy'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Picture_qualtiy'],y=df['current_price'])

# %%
sns.barplot(x=df['Picture_qualtiy'],y=df['MRP'])

# %%
df['Speaker'].value_counts()
# Out:
# 20 W Speaker Output        238
# 24 W Speaker Output         61
# 2 x HDMI | 2 x USB          44
# 40 W Speaker Output         44
# 30 W Speaker Output         42
#                           ...
# 24W x 12 Speaker Output      1
# 24W x 46 Speaker Output      1
# 24W x 11 Speaker Output      1
# 24W x 13 Speaker Output      1
# 8 W x 2 Speaker Output       1
# Name: Speaker, Length: 85, dtype: int64

# %%
df['Speaker'] = df['Speaker'].apply(lambda x:1 if '20 W' in x else 0)

# %%
df['Speaker'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Speaker'],y=df['current_price'])

# %%
sns.barplot(x=df['Speaker'],y=df['MRP'])

# %%
df['Frequency'].value_counts()
# Out:
# 60 Hz Refresh Rate                                                                                     429
# 50 Hz Refresh Rate                                                                                      56
# 100 Hz Refresh Rate                                                                                     25
# 120 Hz Refresh Rate                                                                                     23
# 200 Hz Refresh Rate                                                                                     14
# 3 x HDMI | 2 x USB                                                                                      13
# A+ Grade                                                                                                12
# A+                                                                                                      12
# 1 Year Warranty                                                                                          6
# ...

# %%
df['Frequency'] = df['Frequency'].apply(lambda x:1 if '60 Hz' in x else 0)

# %%
df['Frequency'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Frequency'],y=df['current_price'])

# %%
sns.barplot(x=df['Frequency'],y=df['MRP'])

# %%
df.corr()['MRP']
# Out:
# Stars              -0.097240
# Ratings            -0.085817
# Reviews            -0.100234
# current_price       0.624980
# MRP                 1.000000
# channel            -0.036237
# Operating_system   -0.171926
# Picture_qualtiy     0.466028
# Speaker             0.016103
# Frequency          -0.172357
# Name: MRP, dtype: float64

# %%
df.corr()['current_price']
# Out:
# Stars              -0.139991
# Ratings            -0.091962
# Reviews            -0.109041
# current_price       1.000000
# MRP                 0.624980
# channel            -0.044079
# Operating_system   -0.291564
# Picture_qualtiy     0.416667
# Speaker            -0.032934
# Frequency          -0.327549
# Name: current_price, dtype: float64

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize = (10, 10))
cor=df.corr()
sns.heatmap(cor, annot = True, cmap="YlGnBu")
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.6/210.6 KB 23.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 9.8 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns


sns.set_style("whitegrid")
sns.despine()
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc("axes", labelweight="bold", labelsize="large", titleweight="bold", titlesize=14, titlepad=10)

from scipy import stats


import regex as re
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

import xgboost
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

import optuna

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

seed=42

# %%
X = df.drop(columns=['MRP','current_price','Image_url'])
y = np.log(df['MRP'])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train.head()
# Out:
#     Product_Name  Stars  Ratings  Reviews  channel  Operating_system  \
# 16        Xiaomi    4.3     3120      305        0                 1
# 319      Infinix    4.2    14811     2279        0                 1
# 511      SAMSUNG    5.0        0        0        0                 0
# 865          RGL    4.0     2068      328        0                 0
# 10            Vu    4.4    32043     4978        0                 1
#
#      Picture_qualtiy  Speaker  Frequency
# 16                 0        0          1
# 319                0        1          1
# 511                1        0          0
# 865                0        0          0
# 10                 1        0          1

# %%
X_train.isnull().sum()
# Out:
# Product_Name        0
# Stars               0
# Ratings             0
# Reviews             0
# channel             0
# Operating_system    0
# Picture_qualtiy     0
# Speaker             0
# Frequency           0
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# Product_Name        0
# Stars               0
# Ratings             0
# Reviews             0
# channel             0
# Operating_system    0
# Picture_qualtiy     0
# Speaker             0
# Frequency           0
# dtype: int64
